# %% [markdown]
# # ioNERDSS Tutorial: 6BNO and Synthetic Dodecahedron Workflows
#
# This notebook shows two end-to-end setup patterns:
#
#
# 1. Build a synthetic dodecahedron with `build_system_from_plat(...)`.
# 2. export `nerdss_files/` and then run `nerdss -f parms.inp`.

# %% [markdown]
# ## Imports
#
# The first workflow uses the explicit PDB builder API so you can see where the hyperparameters are applied.

# %%
from pathlib import Path
import subprocess

from ionerdss import build_system_from_pdb, build_system_from_plat
from ionerdss.model.pdb.main import PDBModelBuilder
from ionerdss.model.pdb.hyperparameters import PDBModelHyperparameters
from ionerdss.model.pdb.parser import PDBParser

# %% [markdown]
# ## 1. Build a synthetic dodecahedron and run NERDSS
#
# This matches the requested `build_system_from_plat(...)` workflow.

# %%
save_folder = Path("tutorials_output/dode_tutorial")
save_folder.mkdir(parents=True, exist_ok=True)

sys, rxn = build_system_from_plat(
    solid_type="dode",
    radius=8,
    sigma=1,
    output_nerdss=True,
    output_dir=str(save_folder),
)

print(f"Built {len(sys.molecule_types.molecule_types)} molecule type(s)")
print(f"Built {len(rxn)} reaction rule(s)")
# Out:
# normal = [-0.          3.34219664 -5.40778775]
# Built 1 molecule type(s)
# Built 15 reaction rule(s)

# %%
# Replace with your local nerdss path 
nerdss_cmd = "~/github/JohnsonBiophysicsLab/NERDSS/bin/nerdss -f parms.inp"

print("\nNow running NERDSS simulation...\n")

nerdss_dir = save_folder / "nerdss_files"

subprocess.run(
    nerdss_cmd,
    shell=True,
    cwd=nerdss_dir,
    executable="/bin/bash",
    check=True,
)
# Out:
# Now running NERDSS simulation...
#
# Command: /Users/margaret/github/JohnsonBiophysicsLab/NERDSS/bin/nerdss -f parms.inp
# Start date: 2026-08-20 15:17:28
# RNG Seed: 3639655425
#
# Parsing Input:
# This is a new simulation with input file: parms.inp
# Parsing simulation parameters...
# Read in nItr: 100000 timeSteps
# Read in timeStep: 0.224887 us
# Read in timeWrite: 1000 timeSteps
# Read in trajWrite: 100000 timeSteps
# Read in restartWrite: 100000 timeSteps
# Read in checkPoint: 100000 timeSteps
# Read in pdbWrite: 100000 timeSteps
# Read in overlapSepLimit: 2 nm
# Read in scaleMaxDisplace: 100
# Parsing simulation boundary conditions...
# Read in waterBox: [100 nm, 100 nm, 100 nm]
# Parsing mol file information...
# dode.mol
# Read in checkOverlap: true
# Read in D: [30.6716um^2s^-1, 30.6716um^2s^-1, 30.6716um^2s^-1]
# Read in Dr: [0.359433rad^2s^-1, 0.359433rad^2s^-1, 0.359433rad^2s^-1]
# Coordinates:
# COM: [0nm, 0nm, 0nm]
# dodedode1: [-3.17767nm, 0.878287nm, 0.542811nm]
# dodedode2: [-1.96391nm, -2.29939nm, -1.4211nm]
# dodedode3: [1.96391nm, -2.29939nm, -1.4211nm]
# dodedode4: [3.17767nm, 0.878287nm, 0.542811nm]
# dodedode5: [0nm, 2.8422nm, 1.75657nm]
# Bonds:
# com-dodedode1, com-dodedode2, com-dodedode3, com-dodedode4, com-dodedode5,
# radius calculated from the ifacesCoord: 3.3412 nm
# mass auto calculated from the radius: 3.3412
#
# Parsing reactions...
# Parsing new reaction with form:
#     dode(dodedode1) + dode(dodedode1) <-> dode(dodedode1!1).dode(dodedode1!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 120nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode1) -- Prod: dode(dodedode1)
# Found corresponding interfaces: React: dode(dodedode1) -- Prod: dode(dodedode1)
# Parameter set complete for reaction [dode(dodedode1)+dode(dodedode1)<->dode(dodedode1!1).dode(dodedode1!1)].
#
# Parsing new reaction with form:
#     dode(dodedode2) + dode(dodedode2) <-> dode(dodedode2!1).dode(dodedode2!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 120nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode2) -- Prod: dode(dodedode2)
# Found corresponding interfaces: React: dode(dodedode2) -- Prod: dode(dodedode2)
# Parameter set complete for reaction [dode(dodedode2)+dode(dodedode2)<->dode(dodedode2!1).dode(dodedode2!1)].
#
# Parsing new reaction with form:
#     dode(dodedode3) + dode(dodedode3) <-> dode(dodedode3!1).dode(dodedode3!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 120nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode3) -- Prod: dode(dodedode3)
# Found corresponding interfaces: React: dode(dodedode3) -- Prod: dode(dodedode3)
# Parameter set complete for reaction [dode(dodedode3)+dode(dodedode3)<->dode(dodedode3!1).dode(dodedode3!1)].
#
# Parsing new reaction with form:
#     dode(dodedode4) + dode(dodedode4) <-> dode(dodedode4!1).dode(dodedode4!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 120nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode4) -- Prod: dode(dodedode4)
# Found corresponding interfaces: React: dode(dodedode4) -- Prod: dode(dodedode4)
# Parameter set complete for reaction [dode(dodedode4)+dode(dodedode4)<->dode(dodedode4!1).dode(dodedode4!1)].
#
# Parsing new reaction with form:
#     dode(dodedode5) + dode(dodedode5) <-> dode(dodedode5!1).dode(dodedode5!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 120nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode5) -- Prod: dode(dodedode5)
# Found corresponding interfaces: React: dode(dodedode5) -- Prod: dode(dodedode5)
# Parameter set complete for reaction [dode(dodedode5)+dode(dodedode5)<->dode(dodedode5!1).dode(dodedode5!1)].
#
# Parsing new reaction with form:
#     dode(dodedode1) + dode(dodedode2) <-> dode(dodedode1!1).dode(dodedode2!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode1) -- Prod: dode(dodedode1)
# Found corresponding interfaces: React: dode(dodedode2) -- Prod: dode(dodedode2)
# Parameter set complete for reaction [dode(dodedode1)+dode(dodedode2)<->dode(dodedode1!1).dode(dodedode2!1)].
#
# Parsing new reaction with form:
#     dode(dodedode1) + dode(dodedode3) <-> dode(dodedode1!1).dode(dodedode3!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode1) -- Prod: dode(dodedode1)
# Found corresponding interfaces: React: dode(dodedode3) -- Prod: dode(dodedode3)
# Parameter set complete for reaction [dode(dodedode1)+dode(dodedode3)<->dode(dodedode1!1).dode(dodedode3!1)].
#
# Parsing new reaction with form:
#     dode(dodedode1) + dode(dodedode4) <-> dode(dodedode1!1).dode(dodedode4!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode1) -- Prod: dode(dodedode1)
# Found corresponding interfaces: React: dode(dodedode4) -- Prod: dode(dodedode4)
# Parameter set complete for reaction [dode(dodedode1)+dode(dodedode4)<->dode(dodedode1!1).dode(dodedode4!1)].
#
# Parsing new reaction with form:
#     dode(dodedode1) + dode(dodedode5) <-> dode(dodedode1!1).dode(dodedode5!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode1) -- Prod: dode(dodedode1)
# Found corresponding interfaces: React: dode(dodedode5) -- Prod: dode(dodedode5)
# Parameter set complete for reaction [dode(dodedode1)+dode(dodedode5)<->dode(dodedode1!1).dode(dodedode5!1)].
#
# Parsing new reaction with form:
#     dode(dodedode2) + dode(dodedode3) <-> dode(dodedode2!1).dode(dodedode3!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode2) -- Prod: dode(dodedode2)
# Found corresponding interfaces: React: dode(dodedode3) -- Prod: dode(dodedode3)
# Parameter set complete for reaction [dode(dodedode2)+dode(dodedode3)<->dode(dodedode2!1).dode(dodedode3!1)].
#
# Parsing new reaction with form:
#     dode(dodedode2) + dode(dodedode4) <-> dode(dodedode2!1).dode(dodedode4!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode2) -- Prod: dode(dodedode2)
# Found corresponding interfaces: React: dode(dodedode4) -- Prod: dode(dodedode4)
# Parameter set complete for reaction [dode(dodedode2)+dode(dodedode4)<->dode(dodedode2!1).dode(dodedode4!1)].
#
# Parsing new reaction with form:
#     dode(dodedode2) + dode(dodedode5) <-> dode(dodedode2!1).dode(dodedode5!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode2) -- Prod: dode(dodedode2)
# Found corresponding interfaces: React: dode(dodedode5) -- Prod: dode(dodedode5)
# Parameter set complete for reaction [dode(dodedode2)+dode(dodedode5)<->dode(dodedode2!1).dode(dodedode5!1)].
#
# Parsing new reaction with form:
#     dode(dodedode3) + dode(dodedode4) <-> dode(dodedode3!1).dode(dodedode4!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode3) -- Prod: dode(dodedode3)
# Found corresponding interfaces: React: dode(dodedode4) -- Prod: dode(dodedode4)
# Parameter set complete for reaction [dode(dodedode3)+dode(dodedode4)<->dode(dodedode3!1).dode(dodedode4!1)].
#
# Parsing new reaction with form:
#     dode(dodedode3) + dode(dodedode5) <-> dode(dodedode3!1).dode(dodedode5!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Finished reading reaction parameters, constructing reaction.
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode3) -- Prod: dode(dodedode3)
# Found corresponding interfaces: React: dode(dodedode5) -- Prod: dode(dodedode5)
# Parameter set complete for reaction [dode(dodedode3)+dode(dodedode5)<->dode(dodedode3!1).dode(dodedode5!1)].
#
# Parsing new reaction with form:
#     dode(dodedode4) + dode(dodedode5) <-> dode(dodedode4!1).dode(dodedode5!1)
# Reversible reaction.
# Bimolecular reaction detected.
# Parsing reactants...
# Parsing products...
# Read in value of onRate3Dka: 240nm^3us^-1
# Read in value of offRatekb: 83.276s^-1
# Read in value of norm1: [0i + -0.525731j + 0.850651k]
# Read in value of norm2: [0i + -0.525731j + 0.850651k]
# Read in value of sigma: 1nm
# Read in value of assocAngles: [theta1: 2.58802, theta2: 2.58802, phi1: 0, phi2: 0, omega: 0]
# Checking for valid states for reactant dode
# Checking for valid states for reactant dode
# Found corresponding interfaces: React: dode(dodedode4) -- Prod: dode(dodedode4)
# Found corresponding interfaces: React: dode(dodedode5) -- Prod: dode(dodedode5)
# Parameter set complete for reaction [dode(dodedode4)+dode(dodedode5)<->dode(dodedode4!1).dode(dodedode5!1)].
#
#
# Input file parsing complete
# NUMBER OF MOLECULE TYPES: 1NUMBER OF INTERFACES PLUS STATES, including PRODUCTS: 20
# NUMBER OF MOLECULES IN GEN COORDS: 10
# Finding and fixing overlapping proteins.
# Iteration: 1
# Overlapping Proteins (false): 0
# No overlapping proteins found.
#
# Partitioning simulation box into sub-boxes...
# Rmaxlimit: 36.111
# Simulation volume parameters:
# Total sub-volumes: 16
# 	Dimensions: [2, 2, 4]
# 	Maximum sub-volume neighbors: 13
# 	Sub-volume size: [50, 50, 25]
#  Total species calculated from init_speciesFile.cpp: 20
# Initialized copyNumSpecies. Printing all values. total species: 20
#  absolute index: 0 Copy nums: 10
#  absolute index: 1 Copy nums: 10
#  absolute index: 2 Copy nums: 10
#  absolute index: 3 Copy nums: 10
#  absolute index: 4 Copy nums: 10
#  absolute index: 5 Copy nums: 0
#  absolute index: 6 Copy nums: 0
#  absolute index: 7 Copy nums: 0
#  absolute index: 8 Copy nums: 0
#  absolute index: 9 Copy nums: 0
#  absolute index: 10 Copy nums: 0
#  absolute index: 11 Copy nums: 0
#  absolute index: 12 Copy nums: 0
#  absolute index: 13 Copy nums: 0
#  absolute index: 14 Copy nums: 0
#  absolute index: 15 Copy nums: 0
#  absolute index: 16 Copy nums: 0
#  absolute index: 17 Copy nums: 0
#  absolute index: 18 Copy nums: 0
#  absolute index: 19 Copy nums: 0
# Pro pair:  p1: 0 p2: 0 index: 0 dode,dode'	size of proPairlist: 1 Number of pairs: 1 numMolTypes: 1
#
# Simulation Parameters
# Number of iterations: 100000 timesteps
# Timestep: 0.224887 us
# Timestep log interval (timeWrite): 1000 timesteps
# Restart file write interval: 100000 timesteps
# Coordinate write interval (trajWrite): 100000 timesteps
# PDB Coordinate write interval: 100000 timesteps
# Checkpoint write interval: 100000 timesteps
# overlapSepLimit: 2 nm
# Transition matrix write interval: 10000 timesteps
# ClusterOverlapCheck: false
# RNGwrite: false
# bondedComplexWrite: -1
# Molecule specific parameters:
# Number of unique molecule types: 1
# Total number of unique interfaces and states, including product states: 20
# Total number of complexes in system at start: 10
# Total number of units (molecules + interfaces) in system at start: 60
# Maximum allowed number of unique 2D reactions: 10000
#  isSphere? false
#  sphere Radius 0
#  hasCompartment? false
#  compartment Radius 0
#  BOX geometry, dimensions:
# 100 100 100
#  hasImplicitLipid? false
#
# Molecule Information
# Molecule template 0
# Name: dode
# Copy number:10
#  Diffusion trans: 30.6716 30.6716 30.6716
#  Diffusion Rot: 0.359433 0.359433 0.359433
# Is a promoter: false
# Is a rod: false
# Is a point: false
# Radius: 3.3412
#
# Interfaces:
# Name: dodedode1
# Relative index: 0
# Absolute index: 0
# Forward Reactions:  (0) (5) (6) (7) (8)
#
# Name: dodedode2
# Relative index: 1
# Absolute index: 1
# Forward Reactions:  (1) (5) (9) (10) (11)
#
# Name: dodedode3
# Relative index: 2
# Absolute index: 2
# Forward Reactions:  (2) (6) (9) (12) (13)
#
# Name: dodedode4
# Relative index: 3
# Absolute index: 3
# Forward Reactions:  (3) (7) (10) (12) (14)
#
# Name: dodedode5
# Relative index: 4
# Absolute index: 4
# Forward Reactions:  (4) (8) (11) (13) (14)
#
#
# Reactions
# Forward Rxn: 0
# Absolute index: 0
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode1, iface index: 0, required Free]
#
# Products:
#  [iface name: dodedode1, iface index: 5, requires interaction]
#  [iface name: dodedode1, iface index: 5, requires interaction]
#
# Rate(s):
# Rate 0: 120
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 0
# Absolute index: 1
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 5, requires interaction]
#  [iface name: dodedode1, iface index: 5, requires interaction]
#
# Products:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode1, iface index: 0, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 1
# Absolute index: 2
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode2, iface index: 1, required Free]
#  [iface name: dodedode2, iface index: 1, required Free]
#
# Products:
#  [iface name: dodedode2, iface index: 6, requires interaction]
#  [iface name: dodedode2, iface index: 6, requires interaction]
#
# Rate(s):
# Rate 0: 120
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 1
# Absolute index: 3
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode2, iface index: 6, requires interaction]
#  [iface name: dodedode2, iface index: 6, requires interaction]
#
# Products:
#  [iface name: dodedode2, iface index: 1, required Free]
#  [iface name: dodedode2, iface index: 1, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 2
# Absolute index: 4
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode3, iface index: 2, required Free]
#  [iface name: dodedode3, iface index: 2, required Free]
#
# Products:
#  [iface name: dodedode3, iface index: 7, requires interaction]
#  [iface name: dodedode3, iface index: 7, requires interaction]
#
# Rate(s):
# Rate 0: 120
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 2
# Absolute index: 5
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode3, iface index: 7, requires interaction]
#  [iface name: dodedode3, iface index: 7, requires interaction]
#
# Products:
#  [iface name: dodedode3, iface index: 2, required Free]
#  [iface name: dodedode3, iface index: 2, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 3
# Absolute index: 6
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode4, iface index: 3, required Free]
#  [iface name: dodedode4, iface index: 3, required Free]
#
# Products:
#  [iface name: dodedode4, iface index: 8, requires interaction]
#  [iface name: dodedode4, iface index: 8, requires interaction]
#
# Rate(s):
# Rate 0: 120
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 3
# Absolute index: 7
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode4, iface index: 8, requires interaction]
#  [iface name: dodedode4, iface index: 8, requires interaction]
#
# Products:
#  [iface name: dodedode4, iface index: 3, required Free]
#  [iface name: dodedode4, iface index: 3, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 4
# Absolute index: 8
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode5, iface index: 4, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
# Products:
#  [iface name: dodedode5, iface index: 9, requires interaction]
#  [iface name: dodedode5, iface index: 9, requires interaction]
#
# Rate(s):
# Rate 0: 120
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 4
# Absolute index: 9
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode5, iface index: 9, requires interaction]
#  [iface name: dodedode5, iface index: 9, requires interaction]
#
# Products:
#  [iface name: dodedode5, iface index: 4, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 5
# Absolute index: 10
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode2, iface index: 1, required Free]
#
# Products:
#  [iface name: dodedode1, iface index: 10, requires interaction]
#  [iface name: dodedode2, iface index: 10, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 5
# Absolute index: 11
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 10, requires interaction]
#  [iface name: dodedode2, iface index: 10, requires interaction]
#
# Products:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode2, iface index: 1, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 6
# Absolute index: 12
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode3, iface index: 2, required Free]
#
# Products:
#  [iface name: dodedode1, iface index: 11, requires interaction]
#  [iface name: dodedode3, iface index: 11, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 6
# Absolute index: 13
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 11, requires interaction]
#  [iface name: dodedode3, iface index: 11, requires interaction]
#
# Products:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode3, iface index: 2, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 7
# Absolute index: 14
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode4, iface index: 3, required Free]
#
# Products:
#  [iface name: dodedode1, iface index: 12, requires interaction]
#  [iface name: dodedode4, iface index: 12, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 7
# Absolute index: 15
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 12, requires interaction]
#  [iface name: dodedode4, iface index: 12, requires interaction]
#
# Products:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode4, iface index: 3, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 8
# Absolute index: 16
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
# Products:
#  [iface name: dodedode1, iface index: 13, requires interaction]
#  [iface name: dodedode5, iface index: 13, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 8
# Absolute index: 17
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode1, iface index: 13, requires interaction]
#  [iface name: dodedode5, iface index: 13, requires interaction]
#
# Products:
#  [iface name: dodedode1, iface index: 0, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 9
# Absolute index: 18
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode2, iface index: 1, required Free]
#  [iface name: dodedode3, iface index: 2, required Free]
#
# Products:
#  [iface name: dodedode2, iface index: 14, requires interaction]
#  [iface name: dodedode3, iface index: 14, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 9
# Absolute index: 19
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode2, iface index: 14, requires interaction]
#  [iface name: dodedode3, iface index: 14, requires interaction]
#
# Products:
#  [iface name: dodedode2, iface index: 1, required Free]
#  [iface name: dodedode3, iface index: 2, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 10
# Absolute index: 20
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode2, iface index: 1, required Free]
#  [iface name: dodedode4, iface index: 3, required Free]
#
# Products:
#  [iface name: dodedode2, iface index: 15, requires interaction]
#  [iface name: dodedode4, iface index: 15, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 10
# Absolute index: 21
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode2, iface index: 15, requires interaction]
#  [iface name: dodedode4, iface index: 15, requires interaction]
#
# Products:
#  [iface name: dodedode2, iface index: 1, required Free]
#  [iface name: dodedode4, iface index: 3, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 11
# Absolute index: 22
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode2, iface index: 1, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
# Products:
#  [iface name: dodedode2, iface index: 16, requires interaction]
#  [iface name: dodedode5, iface index: 16, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 11
# Absolute index: 23
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode2, iface index: 16, requires interaction]
#  [iface name: dodedode5, iface index: 16, requires interaction]
#
# Products:
#  [iface name: dodedode2, iface index: 1, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 12
# Absolute index: 24
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode3, iface index: 2, required Free]
#  [iface name: dodedode4, iface index: 3, required Free]
#
# Products:
#  [iface name: dodedode3, iface index: 17, requires interaction]
#  [iface name: dodedode4, iface index: 17, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 12
# Absolute index: 25
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode3, iface index: 17, requires interaction]
#  [iface name: dodedode4, iface index: 17, requires interaction]
#
# Products:
#  [iface name: dodedode3, iface index: 2, required Free]
#  [iface name: dodedode4, iface index: 3, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 13
# Absolute index: 26
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode3, iface index: 2, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
# Products:
#  [iface name: dodedode3, iface index: 18, requires interaction]
#  [iface name: dodedode5, iface index: 18, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 13
# Absolute index: 27
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode3, iface index: 18, requires interaction]
#  [iface name: dodedode5, iface index: 18, requires interaction]
#
# Products:
#  [iface name: dodedode3, iface index: 2, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# Forward Rxn: 14
# Absolute index: 28
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode4, iface index: 3, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
# Products:
#  [iface name: dodedode4, iface index: 19, requires interaction]
#  [iface name: dodedode5, iface index: 19, requires interaction]
#
# Rate(s):
# Rate 0: 240
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# Sigma: 1
# Association angles:
# Theta 1   2.58802
# Theta 2   2.58802
# Phi 1           0
# Phi 2           0
# Omega           0
#
# label: nonspecified
# Is On Membrane: false
# bindRadSameCom 1.1
# loopCoopFactor 1
# length3Dto2D 2
# area3Dto1D 12.5664
# isCoupled? false
#
# Back Rxn: 14
# Absolute index: 29
# Type: Bimolecular association
# Reactants:
#  [iface name: dodedode4, iface index: 19, requires interaction]
#  [iface name: dodedode5, iface index: 19, requires interaction]
#
# Products:
#  [iface name: dodedode4, iface index: 3, required Free]
#  [iface name: dodedode5, iface index: 4, required Free]
#
#
# Rate(s):
# Rate 0: 83.276
# Reactant 1 requires interfaces:
# Reactant 2 requires interfaces:
# On Membrane? false
# *************** BEGIN SIMULATION ****************
# -------------------
# End iteration: 1000, simulation time: 2.248865e-04 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 2
# Total reaction matches: 421524
# Avg timestep duration: 4.527300e-05, iterations remaining: 99000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:32
# -------------------------------------------------
# -------------------
# End iteration: 2000, simulation time: 4.497730e-04 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 2
# Total reaction matches: 491277
# Avg timestep duration: 7.244000e-06, iterations remaining: 98000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 3000, simulation time: 6.746595e-04 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 2
# Total reaction matches: 531483
# Avg timestep duration: 4.495000e-06, iterations remaining: 97000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 4000, simulation time: 8.995460e-04 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 564323
# Avg timestep duration: 4.480000e-06, iterations remaining: 96000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 5000, simulation time: 1.124433e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 580323
# Avg timestep duration: 3.475000e-06, iterations remaining: 95000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 6000, simulation time: 1.349319e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 596323
# Avg timestep duration: 3.120000e-06, iterations remaining: 94000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 7000, simulation time: 1.574206e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 612323
# Avg timestep duration: 3.068000e-06, iterations remaining: 93000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 8000, simulation time: 1.799092e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 628323
# Avg timestep duration: 3.122000e-06, iterations remaining: 92000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 9000, simulation time: 2.023979e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 644323
# Avg timestep duration: 3.079000e-06, iterations remaining: 91000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 10000, simulation time: 2.248865e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 660323
# Avg timestep duration: 3.684000e-06, iterations remaining: 90000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 11000, simulation time: 2.473752e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 676323
# Avg timestep duration: 3.117000e-06, iterations remaining: 89000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 12000, simulation time: 2.698638e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 692323
# Avg timestep duration: 3.038000e-06, iterations remaining: 88000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 13000, simulation time: 2.923525e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 708323
# Avg timestep duration: 3.389000e-06, iterations remaining: 87000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 14000, simulation time: 3.148411e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 724323
# Avg timestep duration: 3.212000e-06, iterations remaining: 86000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 15000, simulation time: 3.373298e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 740323
# Avg timestep duration: 3.687000e-06, iterations remaining: 85000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 16000, simulation time: 3.598184e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 756323
# Avg timestep duration: 3.105000e-06, iterations remaining: 84000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 17000, simulation time: 3.823071e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 772323
# Avg timestep duration: 3.134000e-06, iterations remaining: 83000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 18000, simulation time: 4.047957e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 788323
# Avg timestep duration: 3.095000e-06, iterations remaining: 82000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 19000, simulation time: 4.272844e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 804323
# Avg timestep duration: 3.074000e-06, iterations remaining: 81000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 20000, simulation time: 4.497730e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 820351
# Avg timestep duration: 3.304000e-06, iterations remaining: 80000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 21000, simulation time: 4.722617e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 836351
# Avg timestep duration: 3.029000e-06, iterations remaining: 79000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 22000, simulation time: 4.947503e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 852351
# Avg timestep duration: 3.126000e-06, iterations remaining: 78000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 23000, simulation time: 5.172390e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 868351
# Avg timestep duration: 3.115000e-06, iterations remaining: 77000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 24000, simulation time: 5.397276e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 884351
# Avg timestep duration: 3.094000e-06, iterations remaining: 76000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 25000, simulation time: 5.622163e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 900351
# Avg timestep duration: 3.196000e-06, iterations remaining: 75000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 26000, simulation time: 5.847049e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 916351
# Avg timestep duration: 3.066000e-06, iterations remaining: 74000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 27000, simulation time: 6.071936e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 932351
# Avg timestep duration: 3.106000e-06, iterations remaining: 73000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 28000, simulation time: 6.296822e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 948351
# Avg timestep duration: 3.116000e-06, iterations remaining: 72000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 29000, simulation time: 6.521709e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 964351
# Avg timestep duration: 3.119000e-06, iterations remaining: 71000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 30000, simulation time: 6.746595e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 980351
# Avg timestep duration: 3.139000e-06, iterations remaining: 70000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 31000, simulation time: 6.971482e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 996351
# Avg timestep duration: 3.031000e-06, iterations remaining: 69000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 32000, simulation time: 7.196368e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1012351
# Avg timestep duration: 3.007000e-06, iterations remaining: 68000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 33000, simulation time: 7.421255e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1028351
# Avg timestep duration: 3.039000e-06, iterations remaining: 67000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 34000, simulation time: 7.646141e-03 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1044351
# ...
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1460375
# Avg timestep duration: 3.117000e-06, iterations remaining: 40000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 61000, simulation time: 1.371808e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1476375
# Avg timestep duration: 3.040000e-06, iterations remaining: 39000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 62000, simulation time: 1.394296e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1492375
# Avg timestep duration: 3.142000e-06, iterations remaining: 38000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 63000, simulation time: 1.416785e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1508375
# Avg timestep duration: 3.085000e-06, iterations remaining: 37000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 64000, simulation time: 1.439274e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1524375
# Avg timestep duration: 3.045000e-06, iterations remaining: 36000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 65000, simulation time: 1.461762e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1540375
# Avg timestep duration: 2.989000e-06, iterations remaining: 35000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 66000, simulation time: 1.484251e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1556375
# Avg timestep duration: 3.081000e-06, iterations remaining: 34000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 67000, simulation time: 1.506740e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1572375
# Avg timestep duration: 3.051000e-06, iterations remaining: 33000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 68000, simulation time: 1.529228e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1588375
# Avg timestep duration: 3.145000e-06, iterations remaining: 32000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 69000, simulation time: 1.551717e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1604375
# Avg timestep duration: 3.086000e-06, iterations remaining: 31000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 70000, simulation time: 1.574206e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1620375
# Avg timestep duration: 3.088000e-06, iterations remaining: 30000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 71000, simulation time: 1.596694e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1636375
# Avg timestep duration: 3.071000e-06, iterations remaining: 29000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 72000, simulation time: 1.619183e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1652375
# Avg timestep duration: 3.078000e-06, iterations remaining: 28000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 73000, simulation time: 1.641671e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1668375
# Avg timestep duration: 3.094000e-06, iterations remaining: 27000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 74000, simulation time: 1.664160e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1684375
# Avg timestep duration: 3.098000e-06, iterations remaining: 26000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 75000, simulation time: 1.686649e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1700375
# Avg timestep duration: 3.002000e-06, iterations remaining: 25000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 76000, simulation time: 1.709137e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1716375
# Avg timestep duration: 3.177000e-06, iterations remaining: 24000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 77000, simulation time: 1.731626e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1732375
# Avg timestep duration: 3.155000e-06, iterations remaining: 23000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 78000, simulation time: 1.754115e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1748375
# Avg timestep duration: 3.067000e-06, iterations remaining: 22000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 79000, simulation time: 1.776603e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1764375
# Avg timestep duration: 3.020000e-06, iterations remaining: 21000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 80000, simulation time: 1.799092e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1780375
# Avg timestep duration: 3.107000e-06, iterations remaining: 20000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 81000, simulation time: 1.821581e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1796403
# Avg timestep duration: 3.154000e-06, iterations remaining: 19000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 82000, simulation time: 1.844069e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1812403
# Avg timestep duration: 3.092000e-06, iterations remaining: 18000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 83000, simulation time: 1.866558e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1828403
# Avg timestep duration: 3.092000e-06, iterations remaining: 17000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 84000, simulation time: 1.889047e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1844403
# Avg timestep duration: 3.119000e-06, iterations remaining: 16000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 85000, simulation time: 1.911535e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1860403
# Avg timestep duration: 3.024000e-06, iterations remaining: 15000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 86000, simulation time: 1.934024e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1876403
# Avg timestep duration: 3.033000e-06, iterations remaining: 14000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 87000, simulation time: 1.956513e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1892403
# Avg timestep duration: 3.088000e-06, iterations remaining: 13000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 88000, simulation time: 1.979001e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1908403
# Avg timestep duration: 3.059000e-06, iterations remaining: 12000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 89000, simulation time: 2.001490e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1924403
# Avg timestep duration: 3.228000e-06, iterations remaining: 11000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 90000, simulation time: 2.023979e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1940403
# Avg timestep duration: 3.105000e-06, iterations remaining: 10000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 91000, simulation time: 2.046467e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1956403
# Avg timestep duration: 3.093000e-06, iterations remaining: 9000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 92000, simulation time: 2.068956e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1972403
# Avg timestep duration: 3.117000e-06, iterations remaining: 8000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 93000, simulation time: 2.091444e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 1988403
# Avg timestep duration: 3.197000e-06, iterations remaining: 7000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 94000, simulation time: 2.113933e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 2004403
# Avg timestep duration: 3.087000e-06, iterations remaining: 6000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 95000, simulation time: 2.136422e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 2020403
# Avg timestep duration: 3.132000e-06, iterations remaining: 5000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 96000, simulation time: 2.158910e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 2036403
# Avg timestep duration: 3.071000e-06, iterations remaining: 4000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 97000, simulation time: 2.181399e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 2052403
# Avg timestep duration: 3.143000e-06, iterations remaining: 3000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 98000, simulation time: 2.203888e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 2068403
# Avg timestep duration: 3.116000e-06, iterations remaining: 2000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------
# End iteration: 99000, simulation time: 2.226376e-02 seconds.
# System time: 2026-08-20 15:17:28
# Elapsed time: 0 minutes
# Number of molecules: 10
# Number of complexes: 1
# Total reaction matches: 2084403
# Avg timestep duration: 3.195000e-06, iterations remaining: 1000, Time left: 0 minutes
# Estimated end time: 2026-08-20 15:17:28
# -------------------------------------------------
# -------------------------------------------------
# End simulation
# End date: 2026-08-20 15:17:28
# 	Wall Time: 3.694270e-01 seconds
# CompletedProcess(args='~/github/JohnsonBiophysicsLab/NERDSS/bin/nerdss -f parms.inp', returncode=0)

# %% [markdown]
# ## Output locations
#
# After running the notebook, inspect these directories:
#
# - `tutorials_output/dode_tutorial/nerdss_files/`
